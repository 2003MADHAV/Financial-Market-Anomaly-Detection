# %%
import sys
sys.path.append("C:\\Users\\ASUS\\project\\anomaly-detection")
from Stocks.StocksLoader import *
from Stocks.BuilderStock import *
from Stocks.PlotterStock import plot_signed_anomaly, plotter

# %% [markdown]
# Here in this  notebook we try to  show how the built system works on real stock data.
#  The Stock for this example are the so-called FAANG stocks which consists of:
# Facebook, Amazon, Apple, Netflix and Google

# %%
faang = ['META', 'AMZN', 'AAPL', 'NFLX', 'GOOG']
labels = faang

# %% [markdown]
# Afer thst  the stocks will be used to build a stock DataFrame between a specific time  interval.

# %%
faang_stock = Stocks(faang, labels, start="2014-01-01", stop="2021-10-01")
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %% [markdown]
# ### Plot the detected anomalies in the FAANG stocks.
#
# A plot with all anomalies found and a plot with corrected anomalies are shown in each case.
# A corrected anomaly is one where at least two different features have occurred
# and anylize help of the graph

# %% [markdown]
# Plotting of the wanted stocks with the detected anomalies. The isolation forest was used with the return, difference and realized semi variance feature.

# %%
for label in labels:
    stockDf = pd.DataFrame(faang_stock.df_stocks[label]['Close'])
    df = build_stock(stockDf,N=1,contamin=0.008)
    plotter(df,label,False)
    plot_signed_anomaly(df,label)
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
