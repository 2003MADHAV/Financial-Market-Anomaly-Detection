# %%
import sys
sys.path.append("C:\\Users\\ASUS\\project\\anomaly-detection")
from Stocks.StocksLoader import *
from Stocks.BuilderStock import *
from Stocks.PlotterStock import  plotter

# %% [markdown]
# here this  notebook to show how the built system works on real futures data.
# GC=F: Gold futures contract.
# CL=F: Crude oil futures contract.
# SI=F: Silver futures contract.
# ZS=F: Soybean futures contract.
# KC=F: Coffee futures contract.
# ZC=F: Corn futures contract.
# These symbols are commonly used to denote futures contracts for trading various commodities and financial assets in financial markets.

# %%
futures =  ['GC=F','CL=F','SI=F','ZS=F','KC=F','ZC=F']
labels = futures

# %%
futures_stock = Stocks(futures, labels, start="2014-01-01", stop="2021-10-01")
futures_stock = futures_stock.df_stocks.dropna()
futures_stock
# Out:
# [*********************100%%**********************]  6 of 6 completed
# Stock Ticker         GC=F                                                      \
# Stock Info           Open         High          Low        Close    Adj Close
# Date
# 2014-01-02    1204.300049  1227.300049  1204.300049  1225.000000  1225.000000
# 2014-01-03    1221.699951  1239.000000  1221.699951  1238.400024  1238.400024
# 2014-01-06    1232.800049  1247.000000  1221.900024  1237.800049  1237.800049
# 2014-01-07    1239.300049  1242.400024  1226.300049  1229.400024  1229.400024
# 2014-01-08    1227.500000  1227.500000  1218.599976  1225.300049  1225.300049
# ...                   ...          ...          ...          ...          ...
# 2021-09-24    1749.699951  1749.699951  1745.000000  1749.699951  1749.699951
# 2021-09-27    1751.699951  1754.400024  1747.500000  1750.000000  1750.000000
# 2021-09-28    1739.599976  1741.699951  1726.800049  1735.800049  1735.800049
# ...

# %% [markdown]
# we can plot anomaly graph with future stocks data

# %%
for label in labels:
    stockDf = pd.DataFrame(futures_stock[label]['Close'])
    df = build_stock(stockDf,N=1,contamin=0.008)
    plotter(df,label,False)
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
