# %%
import sys
sys.path.append("C:\\Users\\ASUS\\project\\anomaly-detection")
from sklearn.metrics import f1_score
import Testdata.Builder as Builder

# %% [markdown]
# ### Compare IF vs CutOff
#
# Using the confusionsmatrix, the results of the IF with the RSV feature are compared with the CutOff with RSV feature.

# %%
data = Builder.simulation_test(v=0.055, l=10, step=1000, sigma=0.35,N=1,print_f1=True)
# Out:
# C:\Users\ASUS\project\anomaly-detection\Testdata\Builder.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.82992494 0.97174902 0.84107288 0.82054461 0.7998625  0.77196565
#  0.8421824  0.94092533 1.05618788 0.9254506  0.85575035 0.71607259]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   mertonDf.loc[jumps_x, 'Jumps plot'] = jumpsDf['Merton Jump']
# Anomaly merton: 1 of 12 anomalies (8.0 %) in total: 10
# -----------------------------
# Anomaly Returns IF: 9 of 12 anomalies (75.0 %) in total: 10
# -----------------------------
# Anomaly RSV IF: 8 of 12 anomalies (67.0 %) in total: 10
# -----------------------------
# Anomaly Diff IF: 8 of 12 anomalies (67.0 %) in total: 10
# -----------------------------
# Amomaly RSV Diff: 8 of 12 anomalies (67.0 %) in total: 10
# -----------------------------
# Amomaly Returns RSV Diff: 9 of 12 anomalies (75.0 %) in total: 10
# ...

# %% [markdown]
# ### IF with RSV

# %%
print(Builder.class_report(data,'Anomaly RSV IF'))
print('F1 rsv iff: ', f1_score(data['Jumps'], data['Anomaly RSV IF']))
# Out:
#               precision    recall  f1-score   support
#
#       normal       1.00      1.00      1.00       988
#      outlier       0.80      0.67      0.73        12
#
#     accuracy                           0.99      1000
#    macro avg       0.90      0.83      0.86      1000
# weighted avg       0.99      0.99      0.99      1000
#
# None
# F1 rsv iff:  0.7272727272727272

# %%
cm = Builder.calc_confusion_matrix(data,'Anomaly RSV IF')
Builder.plot_confusion_matrix(cm)

# %% [markdown]
# ### CutOff with RSV

# %%
print('CutOff RSV:')
Builder.class_report(data,'CutOff RSV')
# Out:
# CutOff RSV:
#               precision    recall  f1-score   support
#
#       normal       1.00      1.00      1.00       988
#      outlier       0.80      0.67      0.73        12
#
#     accuracy                           0.99      1000
#    macro avg       0.90      0.83      0.86      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
cm = Builder.calc_confusion_matrix(data,'CutOff RSV')
Builder.plot_confusion_matrix(cm)
